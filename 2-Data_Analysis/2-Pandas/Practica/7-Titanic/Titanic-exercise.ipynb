# %% [markdown]
#    #                                                  Titanic Exercise
#
#    ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)
#    #### Practise Pandas

# %% [markdown]
# First of all, import the needed libraries.

# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import statistics
import csv

# %%
# titanic = sns.load_dataset('Titanic')

# No están los nombres

# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
titanic = pd.read_csv(url)

# %%
titanic_real = pd.read_csv('data/titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
# First way

people = titanic[['Name', 'Sex', 'Age']]

people.head()
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
# Second way

people = titanic.loc[:,['Name', 'Sex', 'Age']]

people.head()
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
# Creo que en la versión de pandas que tengo instalada no se puede usar el método append, al menos no me sale.

pd.concat([people.head(3), people.tail(4)])
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
s_titanic = titanic[3:10].copy()

# %%
s_titanic
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 3      0  113803  53.1000  C123        S
# ...

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
s_titanic_rev = titanic.iloc[63:39:-1].copy()

s_titanic_rev
# Out:
#     PassengerId  Survived  Pclass  \
# 63           64         0       3
# 62           63         0       1
# 61           62         1       1
# 60           61         0       3
# 59           60         0       3
# 58           59         1       2
# 57           58         0       3
# 56           57         1       2
# 55           56         1       1
# 54           55         0       1
# 53           54         1       2
# 52           53         1       1
# 51           52         0       3
# 50           51         0       3
# 49           50         0       3
# 48           49         0       3
# 47           48         1       3
# 46           47         0       3
# 45           46         0       3
# 44           45         1       3
# 43           44         1       2
# 42           43         0       3
# 41           42         0       2
# 40           41         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# ...

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
left_columns = titanic.loc[:, :'Parch']

left_columns
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
middle_columns = titanic.loc[:,'Name':'Age']

middle_columns
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
right_columns = titanic.loc[:,'Ticket':]

right_columns
# Out:
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# ..                ...      ...   ...      ...
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q
#
# [891 rows x 4 columns]

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %%
died_passengers = titanic[titanic['Survived'] == 0]

oldest_person = died_passengers.loc[died_passengers['Age'].idxmax()]

name = oldest_person['Name']
age = oldest_person['Age']
sibsp = oldest_person['SibSp']  # Number of siblings/spouses aboard
parch = oldest_person['Parch']  # Number of parents/children aboard

# Determine if they were traveling alone or with family
if sibsp == 0 and parch == 0:
    travel_status = "Viajaba solo"
else:
    travel_status = f"Viajaba con su familia."

# Print the result
print(f"La persona más vieja que murió fue {name}, a la edad de {age}. {travel_status}.")
# Out:
# La persona más vieja que murió fue Svensson, Mr. Johan, a la edad de 74.0. Viajaba solo.

# %% [markdown]
# In order to give an answer to the second question you should find out which columns give you that info. Usually part of your job as a Data Scientist will be get to know the dataset which you are working with. In this case the columns which give you that info are the following:
#         - 'sibsp' Number of Siblings/Spouses Aboard
#         - 'parch' Number of Parents/Children Aboard

# %%
titanic[titanic['Survived'] == 0][['Name','Age','SibSp','Parch']].sort_values('Age',ascending=False)
# Out:
#                                          Name   Age  SibSp  Parch
# 851                       Svensson, Mr. Johan  74.0      0      0
# 96                  Goldschmidt, Mr. George B  71.0      0      0
# 493                   Artagaveytia, Mr. Ramon  71.0      0      0
# 116                      Connors, Mr. Patrick  70.5      0      0
# 745              Crosby, Capt. Edward Gifford  70.0      1      1
# ..                                        ...   ...    ...    ...
# 859                          Razi, Mr. Raihed   NaN      0      0
# 863         Sage, Miss. Dorothy Edith "Dolly"   NaN      8      2
# 868               van Melkebeke, Mr. Philemon   NaN      0      0
# 878                        Laleff, Mr. Kristo   NaN      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"   NaN      1      2
#
# [549 rows x 4 columns]

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %% [markdown]
# This list of numbers are random, could be different.

# %%
import random

rows = random.sample(range(len(titanic)), 5)

filas_aleatorias = titanic.iloc[rows]

filas_aleatorias
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 388          389         0       3          Sadlier, Mr. Matthew    male
# 798          799         0       3  Ibrahim Shawah, Mr. Yousseff    male
# 582          583         0       2    Downton, Mr. William James    male
# 21            22         1       2         Beesley, Mr. Lawrence    male
# 136          137         1       1  Newsom, Miss. Helen Monypeny  female
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 388   NaN      0      0  367655   7.7292   NaN        Q
# 798  30.0      0      0    2685   7.2292   NaN        C
# 582  54.0      0      0   28403  26.0000   NaN        S
# 21   34.0      0      0  248698  13.0000   D56        S
# 136  19.0      0      2   11752  26.2833   D47        S

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
cols = random.sample(titanic.columns.tolist(), 3)

titanic.loc[:, cols]
# Out:
#      Parch            Ticket     Sex
# 0        0         A/5 21171    male
# 1        0          PC 17599  female
# 2        0  STON/O2. 3101282  female
# 3        0            113803  female
# 4        0            373450    male
# ..     ...               ...     ...
# 886      0            211536    male
# 887      0            112053  female
# 888      2        W./C. 6607  female
# 889      0            111369    male
# 890      0            370376    male
#
# [891 rows x 3 columns]

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
import random

cols = random.sample(titanic.columns.tolist(), 3)

rows = random.sample(range(len(titanic)), 5)

nuevo_titanic = titanic.iloc[rows].loc[:, cols]

nuevo_titanic
# Out:
#      Pclass  PassengerId Embarked
# 16        3           17        Q
# 186       3          187        Q
# 757       2          758        S
# 682       3          683        S
# 217       2          218        S

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %%
array_fe = (titanic['Sex'] == 'female')

print(array_fe)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %% [markdown]
# 14. Rename the column `"sex"` to `"gender"` and filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
titanic = titanic.rename(columns={'Sex': 'gender'})

array_fe = (titanic['gender'] == 'female')

woman_titanic = titanic[array_fe]

woman_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
minor_wo = woman_titanic[titanic["Age"]<18].sort_values('Age')

minor_wo
# Out:
# C:\Users\Francisco\AppData\Local\Temp\ipykernel_9716\3746709946.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   minor_wo = woman_titanic[titanic["Age"]<18].sort_values('Age')
#      PassengerId  Survived  Pclass  \
# 644          645         1       3
# 469          470         1       3
# 381          382         1       3
# 172          173         1       3
# 205          206         0       3
# 530          531         1       2
# 119          120         0       3
# 297          298         0       1
# 479          480         1       3
# 642          643         0       3
# 374          375         0       3
# 43            44         1       2
# 184          185         1       3
# 691          692         1       3
# 750          751         1       2
# 10            11         1       3
# 618          619         1       2
# 233          234         1       3
# 448          449         1       3
# 58            59         1       2
# ...

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
dead_wo = minor_wo[titanic["Survived"]==0]

dead_wo
# Out:
# C:\Users\Francisco\AppData\Local\Temp\ipykernel_9716\3960859816.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dead_wo = minor_wo[titanic["Survived"]==0]
#      PassengerId  Survived  Pclass                                  Name  \
# 205          206         0       3            Strom, Miss. Telma Matilda
# 119          120         0       3     Andersson, Miss. Ellis Anna Maria
# 297          298         0       1          Allison, Miss. Helen Loraine
# 642          643         0       3         Skoog, Miss. Margit Elizabeth
# 374          375         0       3            Palsson, Miss. Stina Viola
# 813          814         0       3    Andersson, Miss. Ebba Iris Alfrida
# 24            25         0       3         Palsson, Miss. Torborg Danira
# 541          542         0       3  Andersson, Miss. Ingeborg Constanzia
# 634          635         0       3                    Skoog, Miss. Mabel
# ...

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
titanic_sin_nan = titanic.dropna(how='any')

print("Forma del DataFrame sin NaN:", titanic_sin_nan.shape)
# Out:
# Forma del DataFrame sin NaN: (183, 12)

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
titanic

titanic_sin_nan = titanic.dropna(how='all')

print("Forma del DataFrame sin NaN:", titanic_sin_nan.shape)
# Out:
# Forma del DataFrame sin NaN: (891, 12)

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
titanic

missing_values = titanic.isnull().sum()

columnas_a_eliminar = missing_values[missing_values > 1000].index

titanic_filtrado = titanic.drop(columns=columnas_a_eliminar)

print("Columnas restantes:", titanic_filtrado.columns.tolist())
# Out:
# Columnas restantes: ['PassengerId', 'Survived', 'Pclass', 'Name', 'gender', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
titanic_real.boat.isnull()
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306     True
# 1307     True
# 1308     True
# Name: boat, Length: 1309, dtype: bool

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` and assign it to `by_class`

# %%
by_class = titanic.groupby('Pclass').agg(
    max_age=('Age', 'max'),
    median_age=('Age', 'median'),
    max_fare=('Fare', 'max'),
    median_fare=('Fare', 'median')
)

# Reset index if you want `pclass` as a column instead of the index
by_class = by_class.reset_index()
by_class
# Out:
#    Pclass  max_age  median_age  max_fare  median_fare
# 0       1     80.0        37.0  512.3292      60.2875
# 1       2     70.0        29.0   73.5000      14.2500
# 2       3     74.0        24.0   69.5500       8.0500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
print(by_class['max_age'])
# Out:
# 0    80.0
# 1    70.0
# 2    74.0
# Name: max_age, dtype: float64

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
print(by_class['median_age'])
# Out:
# 0    37.0
# 1    29.0
# 2    24.0
# Name: median_age, dtype: float64

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
import pandas as pd

counted = pd.pivot_table(
    titanic,
    values='Survived',  
    index='Pclass',     
    columns='gender',      
    aggfunc='sum'       
)

counted = counted.reset_index()

counted
# Out:
# gender  Pclass  female  male
# 0            1      91    45
# 1            2      70    17
# 2            3      72    47

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
counted['total'] = counted['female'] + counted['male']

counted
# Out:
# gender  Pclass  female  male  total
# 0            1      91    45    136
# 1            2      70    17     87
# 2            3      72    47    119

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the most?

# %%
print(counted.sort_values(by='total', ascending=False))
print("La clase que sobrevivió más fue la primera")
# Out:
# gender  Pclass  female  male  total
# 0            1      91    45    136
# 2            3      72    47    119
# 1            2      70    17     87
# La clase que sobrevivió más fue la primera

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
conditions = titanic[(titanic['gender'] == 'female') & (titanic['Pclass'] == 3) & (titanic['Age'] < 30) & (titanic['Survived'] == 1)]

print(f"{conditions.shape[0]} filas cumplen estas condiciones")
# Out:
# 39 filas cumplen estas condiciones

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
conditions_m = titanic.loc[(titanic['gender'] == 'male') & (titanic['Pclass'] == 3) & (titanic['Age'] > 50) & (titanic['Survived'] == 0)]


print(f"{conditions_m.shape[0]} filas cumplen estas condiciones")
# Out:
# 9 filas cumplen estas condiciones

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
print(titanic_real['name'].nunique)
# Out:
# <bound method IndexOpsMixin.nunique of 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object>

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
duplicate_names = titanic[titanic.duplicated('Name', keep=False)]

duplicate_names_grouped = duplicate_names.groupby('Name').size().reset_index(name='Count')

repeated_names = duplicate_names_grouped[duplicate_names_grouped['Count'] == 2]

repeated_names

print("No parece que haya nombres duplicados")
# Out:
# No parece que haya nombres duplicados

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
plt.hist(titanic_real['age'],bins=20)
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.title("Distribución de edades")

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
titanic['gender'].value_counts()
plt.figure(figsize=(7,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 titanic['gender'].value_counts()
#       2 plt.figure(figsize=(7,6))
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.<>
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](./img/kdeplotsur.png)

# %% [markdown]
# *Francisco Olivenza Millón*
