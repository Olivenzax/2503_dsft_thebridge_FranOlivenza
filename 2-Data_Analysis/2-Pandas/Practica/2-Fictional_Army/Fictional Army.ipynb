# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 1. This is the data given as a dictionary. Create a dataframe and assign it to a variable called army.

# %%
# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, None, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, None, 3, None, 2, None, 2, None, None, 1, 2, None],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %%
fictional_army = pd.DataFrame(raw_data)

fictional_army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st   523.0        5  1045         1        1.0        1
# 1   Nighthawks     1st    52.0       42   957         5        NaN        0
# 2   Nighthawks     2nd    25.0        2  1099        62        3.0        1
# 3   Nighthawks     2nd   616.0        2  1400        26        NaN        1
# 4     Dragoons     1st    43.0        4  1592        73        2.0        0
# 5     Dragoons     1st   234.0        7  1006        37        NaN        1
# 6     Dragoons     2nd   523.0        8   987       949        2.0        0
# 7     Dragoons     2nd    62.0        3   849        48        NaN        1
# 8       Scouts     1st     NaN        4   973        48        NaN        0
# 9       Scouts     1st    73.0        7  1005       435        1.0        0
# 10      Scouts     2nd    37.0        8  1099        63        2.0        1
# 11      Scouts     2nd    35.0        9  1523       345        NaN        1
#
#     deserters      origin
# 0           4     Arizona
# 1          24  California
# 2          31       Texas
# 3           2     Florida
# 4           3       Maine
# 5           4        Iowa
# 6          24      Alaska
# 7          31  Washington
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %% [markdown]
# ### Step 2. Check missing values

# %%
fictional_army.isnull()
# Out:
#     regiment  company  deaths  battles   size  veterans  readiness  armored  \
# 0      False    False   False    False  False     False      False    False
# 1      False    False   False    False  False     False       True    False
# 2      False    False   False    False  False     False      False    False
# 3      False    False   False    False  False     False       True    False
# 4      False    False   False    False  False     False      False    False
# 5      False    False   False    False  False     False       True    False
# 6      False    False   False    False  False     False      False    False
# 7      False    False   False    False  False     False       True    False
# 8      False    False    True    False  False     False       True    False
# 9      False    False   False    False  False     False      False    False
# 10     False    False   False    False  False     False      False    False
# 11     False    False   False    False  False     False       True    False
#
#     deserters  origin
# 0       False   False
# 1       False   False
# 2       False   False
# 3       False   False
# 4       False   False
# 5       False   False
# 6       False   False
# 7       False   False
# 8       False   False
# 9       False   False
# 10      False   False
# 11      False   False

# %%
fictional_army.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   regiment   12 non-null     object
#  1   company    12 non-null     object
#  2   deaths     11 non-null     float64
#  3   battles    12 non-null     int64
#  4   size       12 non-null     int64
#  5   veterans   12 non-null     int64
#  6   readiness  6 non-null      float64
#  7   armored    12 non-null     int64
#  8   deserters  12 non-null     int64
#  9   origin     12 non-null     object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 1.1+ KB

# %% [markdown]
# ### Step 3. Drop features, if there are more than 30% missing values.

# %%
# En este caso el atributo 'readiness' tiene la mitad de sus valores nulos. 
# Tenemos que hallar la media de porcentajes nulos y multiplicarla por 100, eso nos dará que readiness está en el 50% de missing values.
missing_percentage = fictional_army.isnull().mean() * 100
# Se crea una variable para llamar a las columnas que superen este 30%.
columns_to_drop = missing_percentage[missing_percentage > 30].index
# Se eliminan las columnas que superan ese porcentaje.
fictional_army = fictional_army.drop(columns=columns_to_drop)

fictional_army
# Out:
#       regiment company  deaths  battles  size  veterans  armored  deserters  \
# 0   Nighthawks     1st   523.0        5  1045         1        1          4
# 1   Nighthawks     1st    52.0       42   957         5        0         24
# 2   Nighthawks     2nd    25.0        2  1099        62        1         31
# 3   Nighthawks     2nd   616.0        2  1400        26        1          2
# 4     Dragoons     1st    43.0        4  1592        73        0          3
# 5     Dragoons     1st   234.0        7  1006        37        1          4
# 6     Dragoons     2nd   523.0        8   987       949        0         24
# 7     Dragoons     2nd    62.0        3   849        48        1         31
# 8       Scouts     1st     NaN        4   973        48        0          2
# 9       Scouts     1st    73.0        7  1005       435        0          3
# 10      Scouts     2nd    37.0        8  1099        63        1          2
# 11      Scouts     2nd    35.0        9  1523       345        1          3
#
#         origin
# 0      Arizona
# 1   California
# 2        Texas
# 3      Florida
# 4        Maine
# 5         Iowa
# 6       Alaska
# 7   Washington
# 8       Oregon
# 9      Wyoming
# 10    Louisana
# 11     Georgia

# %% [markdown]
# ### Step 4. Fill missing values with the mean of their regiment.

# %%
fictional_army['deaths'].fillna(fictional_army['deaths'].mean(),inplace=True)
# Out:
# C:\Users\Francisco\AppData\Local\Temp\ipykernel_11932\3668901083.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fictional_army['deaths'].fillna(fictional_army['deaths'].mean(),inplace=True)

# %%
round(fictional_army)
# Out:
#       regiment company  deaths  battles  size  veterans  armored  deserters  \
# 0   Nighthawks     1st   523.0        5  1045         1        1          4
# 1   Nighthawks     1st    52.0       42   957         5        0         24
# 2   Nighthawks     2nd    25.0        2  1099        62        1         31
# 3   Nighthawks     2nd   616.0        2  1400        26        1          2
# 4     Dragoons     1st    43.0        4  1592        73        0          3
# 5     Dragoons     1st   234.0        7  1006        37        1          4
# 6     Dragoons     2nd   523.0        8   987       949        0         24
# 7     Dragoons     2nd    62.0        3   849        48        1         31
# 8       Scouts     1st   202.0        4   973        48        0          2
# 9       Scouts     1st    73.0        7  1005       435        0          3
# 10      Scouts     2nd    37.0        8  1099        63        1          2
# 11      Scouts     2nd    35.0        9  1523       345        1          3
#
#         origin
# 0      Arizona
# 1   California
# 2        Texas
# 3      Florida
# 4        Maine
# 5         Iowa
# 6       Alaska
# 7   Washington
# 8       Oregon
# 9      Wyoming
# 10    Louisana
# 11     Georgia

# %%
fictional_army['deaths'].fillna(fictional_army.groupby('regiment')['deaths'].transform("mean").round(1))
# Out:
# 0     523.000000
# 1      52.000000
# 2      25.000000
# 3     616.000000
# 4      43.000000
# 5     234.000000
# 6     523.000000
# 7      62.000000
# 8     202.090909
# 9      73.000000
# 10     37.000000
# 11     35.000000
# Name: deaths, dtype: float64

# %% [markdown]
# ### Step 5. Set the 'origin' colum as the index of the dataframe

# %%
fictional_army = fictional_army.reset_index()
print("\nDataFrame después de reset_index:")
fictional_army
# Out:
# DataFrame después de reset_index:
#     index    regiment company      deaths  battles  size  veterans  armored  \
# 0       0  Nighthawks     1st  523.000000        5  1045         1        1
# 1       1  Nighthawks     1st   52.000000       42   957         5        0
# 2       2  Nighthawks     2nd   25.000000        2  1099        62        1
# 3       3  Nighthawks     2nd  616.000000        2  1400        26        1
# 4       4    Dragoons     1st   43.000000        4  1592        73        0
# 5       5    Dragoons     1st  234.000000        7  1006        37        1
# 6       6    Dragoons     2nd  523.000000        8   987       949        0
# 7       7    Dragoons     2nd   62.000000        3   849        48        1
# 8       8      Scouts     1st  202.090909        4   973        48        0
# 9       9      Scouts     1st   73.000000        7  1005       435        0
# 10     10      Scouts     2nd   37.000000        8  1099        63        1
# 11     11      Scouts     2nd   35.000000        9  1523       345        1
#
#     deserters      origin
# 0           4     Arizona
# 1          24  California
# 2          31       Texas
# 3           2     Florida
# 4           3       Maine
# 5           4        Iowa
# 6          24      Alaska
# 7          31  Washington
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %%
fictional_army
# Out:
#     index    regiment company      deaths  battles  size  veterans  armored  \
# 0       0  Nighthawks     1st  523.000000        5  1045         1        1
# 1       1  Nighthawks     1st   52.000000       42   957         5        0
# 2       2  Nighthawks     2nd   25.000000        2  1099        62        1
# 3       3  Nighthawks     2nd  616.000000        2  1400        26        1
# 4       4    Dragoons     1st   43.000000        4  1592        73        0
# 5       5    Dragoons     1st  234.000000        7  1006        37        1
# 6       6    Dragoons     2nd  523.000000        8   987       949        0
# 7       7    Dragoons     2nd   62.000000        3   849        48        1
# 8       8      Scouts     1st  202.090909        4   973        48        0
# 9       9      Scouts     1st   73.000000        7  1005       435        0
# 10     10      Scouts     2nd   37.000000        8  1099        63        1
# 11     11      Scouts     2nd   35.000000        9  1523       345        1
#
#     deserters      origin
# 0           4     Arizona
# 1          24  California
# 2          31       Texas
# 3           2     Florida
# 4           3       Maine
# 5           4        Iowa
# 6          24      Alaska
# 7          31  Washington
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %%
fictional_army = fictional_army.set_index("origin")

fictional_army
# Out:
#             index    regiment company      deaths  battles  size  veterans  \
# origin
# Arizona         0  Nighthawks     1st  523.000000        5  1045         1
# California      1  Nighthawks     1st   52.000000       42   957         5
# Texas           2  Nighthawks     2nd   25.000000        2  1099        62
# Florida         3  Nighthawks     2nd  616.000000        2  1400        26
# Maine           4    Dragoons     1st   43.000000        4  1592        73
# Iowa            5    Dragoons     1st  234.000000        7  1006        37
# Alaska          6    Dragoons     2nd  523.000000        8   987       949
# Washington      7    Dragoons     2nd   62.000000        3   849        48
# Oregon          8      Scouts     1st  202.090909        4   973        48
# Wyoming         9      Scouts     1st   73.000000        7  1005       435
# Louisana       10      Scouts     2nd   37.000000        8  1099        63
# Georgia        11      Scouts     2nd   35.000000        9  1523       345
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ### Step 6. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
fictional_army.reset_index('origin')
# Out:
#         origin  index    regiment company      deaths  battles  size  \
# 0      Arizona      0  Nighthawks     1st  523.000000        5  1045
# 1   California      1  Nighthawks     1st   52.000000       42   957
# 2        Texas      2  Nighthawks     2nd   25.000000        2  1099
# 3      Florida      3  Nighthawks     2nd  616.000000        2  1400
# 4        Maine      4    Dragoons     1st   43.000000        4  1592
# 5         Iowa      5    Dragoons     1st  234.000000        7  1006
# 6       Alaska      6    Dragoons     2nd  523.000000        8   987
# 7   Washington      7    Dragoons     2nd   62.000000        3   849
# 8       Oregon      8      Scouts     1st  202.090909        4   973
# 9      Wyoming      9      Scouts     1st   73.000000        7  1005
# 10    Louisana     10      Scouts     2nd   37.000000        8  1099
# 11     Georgia     11      Scouts     2nd   35.000000        9  1523
#
#     veterans  armored  deserters
# 0          1        1          4
# 1          5        0         24
# 2         62        1         31
# 3         26        1          2
# 4         73        0          3
# 5         37        1          4
# 6        949        0         24
# 7         48        1         31
# 8         48        0          2
# 9        435        0          3
# 10        63        1          2
# 11       345        1          3

# %%
filtered_data = fictional_army[fictional_army['origin'].isin(["Maine", "Alaska"])]

# Paso 2: Seleccionar las columnas
result = filtered_data[["origin","deaths", "size", "deserters"]]

result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Francisco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'origin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 filtered_data = fictional_army[fictional_army['origin'].isin(["Maine", "Alaska"])]
#       3 # Paso 2: Seleccionar las columnas
#       4 result = filtered_data[["origin","deaths", "size", "deserters"]]
#
# File c:\Users\Francisco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Francisco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'origin'

# %%
fictional_army.loc[["Maine","Alaska"]][["deaths","size","deserters"]]
# Out:
#         deaths  size  deserters
# origin
# Maine     43.0  1592          3
# Alaska   523.0   987         24

# %% [markdown]
# ### Step 7. Select the rows 3 to 7 and the columns 3 to 6

# %%
fictional_army.iloc[3:8, 3:7]
# Out:
#   company  deaths  battles  size
# 3     2nd   616.0        2  1400
# 4     1st    43.0        4  1592
# 5     1st   234.0        7  1006
# 6     2nd   523.0        8   987
# 7     2nd    62.0        3   849

# %% [markdown]
# ### Step 8. Select every row after the fourth row and all columns

# %%
fictional_army.iloc[4:, :]
# Out:
#     index      origin  regiment company      deaths  battles  size  veterans  \
# 4       4       Maine  Dragoons     1st   43.000000        4  1592        73
# 5       5        Iowa  Dragoons     1st  234.000000        7  1006        37
# 6       6      Alaska  Dragoons     2nd  523.000000        8   987       949
# 7       7  Washington  Dragoons     2nd   62.000000        3   849        48
# 8       8      Oregon    Scouts     1st  202.090909        4   973        48
# 9       9     Wyoming    Scouts     1st   73.000000        7  1005       435
# 10     10    Louisana    Scouts     2nd   37.000000        8  1099        63
# 11     11     Georgia    Scouts     2nd   35.000000        9  1523       345
#
#     armored  deserters
# 4         0          3
# 5         1          4
# 6         0         24
# 7         1         31
# 8         0          2
# 9         0          3
# 10        1          2
# 11        1          3

# %% [markdown]
# ### Step 9. Select every row up to the 4th row and all columns

# %%
fictional_army.iloc[:4, :]
# Out:
#    index      origin    regiment company  deaths  battles  size  veterans  \
# 0      0     Arizona  Nighthawks     1st   523.0        5  1045         1
# 1      1  California  Nighthawks     1st    52.0       42   957         5
# 2      2       Texas  Nighthawks     2nd    25.0        2  1099        62
# 3      3     Florida  Nighthawks     2nd   616.0        2  1400        26
#
#    armored  deserters
# 0        1          4
# 1        0         24
# 2        1         31
# 3        1          2

# %% [markdown]
# ### Step 10. Select the 3rd column up to the 7th column

# %%
fictional_army.iloc[:, 2:7]
# Out:
#       regiment company      deaths  battles  size
# 0   Nighthawks     1st  523.000000        5  1045
# 1   Nighthawks     1st   52.000000       42   957
# 2   Nighthawks     2nd   25.000000        2  1099
# 3   Nighthawks     2nd  616.000000        2  1400
# 4     Dragoons     1st   43.000000        4  1592
# 5     Dragoons     1st  234.000000        7  1006
# 6     Dragoons     2nd  523.000000        8   987
# 7     Dragoons     2nd   62.000000        3   849
# 8       Scouts     1st  202.090909        4   973
# 9       Scouts     1st   73.000000        7  1005
# 10      Scouts     2nd   37.000000        8  1099
# 11      Scouts     2nd   35.000000        9  1523

# %% [markdown]
# ### Step 11. Select rows where df.deaths is greater than 50

# %%
fictional_army[fictional_army["deaths"]>50]
# Out:
#    index      origin    regiment company      deaths  battles  size  veterans  \
# 0      0     Arizona  Nighthawks     1st  523.000000        5  1045         1
# 1      1  California  Nighthawks     1st   52.000000       42   957         5
# 3      3     Florida  Nighthawks     2nd  616.000000        2  1400        26
# 5      5        Iowa    Dragoons     1st  234.000000        7  1006        37
# 6      6      Alaska    Dragoons     2nd  523.000000        8   987       949
# 7      7  Washington    Dragoons     2nd   62.000000        3   849        48
# 8      8      Oregon      Scouts     1st  202.090909        4   973        48
# 9      9     Wyoming      Scouts     1st   73.000000        7  1005       435
#
#    armored  deserters
# 0        1          4
# 1        0         24
# 3        1          2
# 5        1          4
# 6        0         24
# 7        1         31
# 8        0          2
# 9        0          3

# %% [markdown]
# ### Step 12. Select rows where df.deaths is greater than 500 or less than 50

# %%
fictional_army[(fictional_army["deaths"]>500) | (fictional_army["deaths"]<50)]
# Out:
#     index    origin    regiment company  deaths  battles  size  veterans  \
# 0       0   Arizona  Nighthawks     1st   523.0        5  1045         1
# 2       2     Texas  Nighthawks     2nd    25.0        2  1099        62
# 3       3   Florida  Nighthawks     2nd   616.0        2  1400        26
# 4       4     Maine    Dragoons     1st    43.0        4  1592        73
# 6       6    Alaska    Dragoons     2nd   523.0        8   987       949
# 10     10  Louisana      Scouts     2nd    37.0        8  1099        63
# 11     11   Georgia      Scouts     2nd    35.0        9  1523       345
#
#     armored  deserters
# 0         1          4
# 2         1         31
# 3         1          2
# 4         0          3
# 6         0         24
# 10        1          2
# 11        1          3

# %% [markdown]
# ### Step 13. Select all the regiments not named "Dragoons"

# %%
fictional_army[(fictional_army["regiment"]!="Dragoons")]
# Out:
#     index      origin    regiment company      deaths  battles  size  \
# 0       0     Arizona  Nighthawks     1st  523.000000        5  1045
# 1       1  California  Nighthawks     1st   52.000000       42   957
# 2       2       Texas  Nighthawks     2nd   25.000000        2  1099
# 3       3     Florida  Nighthawks     2nd  616.000000        2  1400
# 8       8      Oregon      Scouts     1st  202.090909        4   973
# 9       9     Wyoming      Scouts     1st   73.000000        7  1005
# 10     10    Louisana      Scouts     2nd   37.000000        8  1099
# 11     11     Georgia      Scouts     2nd   35.000000        9  1523
#
#     veterans  armored  deserters
# 0          1        1          4
# 1          5        0         24
# 2         62        1         31
# 3         26        1          2
# 8         48        0          2
# 9        435        0          3
# 10        63        1          2
# 11       345        1          3

# %% [markdown]
# ### Step 14. Select the rows called Texas and Arizona

# %%
fictional_army[(fictional_army["origin"] == "Texas" ) | (fictional_army["origin"] =="Arizona")]
# Out:
#    index   origin    regiment company  deaths  battles  size  veterans  \
# 0      0  Arizona  Nighthawks     1st   523.0        5  1045         1
# 2      2    Texas  Nighthawks     2nd    25.0        2  1099        62
#
#    armored  deserters
# 0        1          4
# 2        1         31

# %% [markdown]
# ### Step 15. Select the third cell in the row named Arizona

# %%
fictional_army = fictional_army.reset_index()
print("\nDataFrame después de reset_index:")
fictional_army
# Out:
# DataFrame después de reset_index:
#     level_0  index      origin    regiment company      deaths  battles  size  \
# 0         0      0     Arizona  Nighthawks     1st  523.000000        5  1045
# 1         1      1  California  Nighthawks     1st   52.000000       42   957
# 2         2      2       Texas  Nighthawks     2nd   25.000000        2  1099
# 3         3      3     Florida  Nighthawks     2nd  616.000000        2  1400
# 4         4      4       Maine    Dragoons     1st   43.000000        4  1592
# 5         5      5        Iowa    Dragoons     1st  234.000000        7  1006
# 6         6      6      Alaska    Dragoons     2nd  523.000000        8   987
# 7         7      7  Washington    Dragoons     2nd   62.000000        3   849
# 8         8      8      Oregon      Scouts     1st  202.090909        4   973
# 9         9      9     Wyoming      Scouts     1st   73.000000        7  1005
# 10       10     10    Louisana      Scouts     2nd   37.000000        8  1099
# 11       11     11     Georgia      Scouts     2nd   35.000000        9  1523
#
#     veterans  armored  deserters
# 0          1        1          4
# 1          5        0         24
# 2         62        1         31
# 3         26        1          2
# 4         73        0          3
# 5         37        1          4
# 6        949        0         24
# 7         48        1         31
# 8         48        0          2
# 9        435        0          3
# 10        63        1          2
# 11       345        1          3

# %%
fictional_army["Arizona"][3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Francisco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Arizona'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 fictional_army["Arizona"][3]
#
# File c:\Users\Francisco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Francisco\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Arizona'

# %% [markdown]
# ### Step 16. Select the third cell down in the column named deaths

# %%
print(fictional_army.deaths[2])
# Out:
# 25.0

# %% [markdown]
# *Francisco Olivenza Millón*
