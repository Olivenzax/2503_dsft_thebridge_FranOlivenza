# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Flujos de control

# %% [markdown]
# ## Ejercicio Extra
# Programa una calculadora que
#
# * Pregunte qué operación quieres realizar (multiplicación/división/suma/resta/potencia/salir)
# * Pida dos números
# * Realice la operación
# * Siga funcionando hasta que el usuario elija salir
#
# #### Bonus:
# * Que guarde todas las operaciones realizadas y las imprima por pantalla cuando el usuario elija esa opción
# * Que sea robusta frente a entradas erróneas del usuario o frente a operaciones como dividir por 0

# %%
import time

operacion_tipos = ["Multiplicación","División","Suma","Resta","Potencia","Historial","Salir"]
historial = []

print("Bienvenido a la calculadora")
print()

time.sleep(1)
while True:
    print("Seleccione de la siguiente lista la operación que quiere realizar.\n\t\t(Si lo desea, también puede finalizar escribiendo 'Salir')")
    print()
    for op in range(len(operacion_tipos)):
        print(op+1, operacion_tipos[op])
    time.sleep(1)
    print()
    operacion_form = str(input("¿Qué operación quieres realizar?"))
    if operacion_form == "Salir":
        print("Gracias por usar esta calculadora")
        break
    elif operacion_form == "Historial":
            if historial == []:
                print("No ha realizado ninguna operación por el momento... Volviendo a la interfaz.")
                time.sleep(2)
                print("Bienvenido de nuevo a la calculadora")
                print()
            else:
                print("Este es su historial:")
                print()
                for re in range(len(historial)):
                    print(re+1,".", historial[re])
                time.sleep(2)
                print()
                print("Bienvenido de nuevo a la calculadora")
                time.sleep(1)
                print()
    else:
        num_1 = float(input("Escriba el primer número:"))
        num_2 = float(input("Escriba el segundo número:"))
        if operacion_form == "Multiplicación":
            print(f"Has elegido multiplicar {num_1} por {num_2} y el resultado es", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print(">", end=" ")
            time.sleep(1)
            resultado = num_1*num_2
            print(resultado)
            historial.append(f"{num_1} x {num_2} = {resultado}")
            print()
            time.sleep(2)
            print("Bienvenido de nuevo a la calculadora")
            print()
        elif operacion_form == "División":
            print(f"Has elegido dividir {num_1} entre {num_2} y el resultado es", end=" ")
            if num_2 == 0:
                print("Indefinido.")
                time.sleep(1)
                print("Imagínate que tienes cero galletas y la repartes entre cero amigos. \n¿Cuántas galletas le tocan a cada amigo? No tiene sentido, ¿lo ves? \nAsí que el Monstruo de las galletas está triste porque no tiene galletas \ny tu estás triste porque no tienes amigos")
                print()
                time.sleep(2)
                print("Bienvenido de nuevo a la calculadora")
                print()
            else:
                time.sleep(0.25)
                print("-", end=" ")
                time.sleep(0.25)
                print("-", end=" ")
                time.sleep(0.25)
                print("-", end=" ")
                time.sleep(0.25)
                print(">", end=" ")
                time.sleep(1)
                resultado = num_1/num_2
                print(resultado)
                historial.append(f"{num_1} / {num_2} = {resultado}")
                print()
                time.sleep(2)
                print("Bienvenido de nuevo a la calculadora")
                print()
        elif operacion_form == "Suma":
            print(f"Has elegido sumar {num_1} y {num_2} y el resultado es", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print(">", end=" ")
            time.sleep(1)
            resultado = num_1+num_2
            print(resultado)
            historial.append(f"{num_1} + {num_2} = {resultado}")
            print()
            time.sleep(2)
            print("Bienvenido de nuevo a la calculadora")
            print()
        elif operacion_form == "Resta":
            print(f"Has elegido restar {num_1} y {num_2} y el resultado es", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print(">", end=" ")
            time.sleep(1)
            resultado = num_1-num_2
            print(resultado)
            historial.append(f"{num_1} - {num_2} = {resultado}")
            print()
            time.sleep(2)
            print("Bienvenido de nuevo a la calculadora")
            print()
        elif operacion_form == "Potencia":
            print(f"Has elegido elevar {num_1} en potencia {num_2} y el resultado es", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print("-", end=" ")
            time.sleep(0.25)
            print(">", end=" ")
            time.sleep(1)
            resultado = num_1**num_2
            print(resultado)
            historial.append(f"{num_1}^{num_2} = {resultado}")
            print()
            time.sleep(2)
            print("Bienvenido de nuevo a la calculadora")
            print()
        else:
            print("No es una operación contemplada en la lista.\n\t Lo siento, no podemos ayudarte con eso...")
            time.sleep(2)
            print("Bienvenido de nuevo a la calculadora")
            print()
# Out:
# Bienvenido a la calculadora
#
# Seleccione de la siguiente lista la operación que quiere realizar.
# 		(Si lo desea, también puede finalizar escribiendo 'Salir')
#
# 1 Multiplicación
# 2 División
# 3 Suma
# 4 Resta
# 5 Potencia
# 6 Historial
# 7 Salir
#
# Gracias por usar esta calculadora

# %% [markdown]
# # Te adjunto el ejercicio 9 del otro archivo de Ejercicios_Flujos_Control.

# %% [markdown]
# ## Ejercicio 9
# En este ejercicio vamos a crear un pequeño juego. Se trata de intentar adivinar un numero del 1 al 5. Tenemos dos intentos para acertar. Pasos a seguir:
#
# 1. Ya viene implementado con la librería `random` cómo obtener un número aleatorio del 1 al 5
# 2. Tendrás que declarar en una variable el numero de vidas, y mediante un bucle while, comprobar que todavia quedan vidas.
# 3. Dentro del bucle, obtener el valor del usuario y comprobar si es ese el numero a adivinar. Si no, actualizar las vidas.
# 4. Si acertamos, salimos del bucle e imprimimos por pantalla "You win". Y si perdemos también salimos del bucle, pero en este caso imprimimos por pantalla "You lose".
#
# TIP: te puede resultar útil usar la sentencia `else` cuando acabe el bucle `while`. Lo que haya dentro de ese `else` se ejecutará una vez acabe la ejecución del `while`. Lo podrás usar para cuando pierdas.

# %%
import random

print("¡Bienvenido de al juego! Elige sabiamente un número del 1 al 5")
print()
# De la siguiente forma se genera un número aleatorio entre esos dos.
num_aleatorio = random.randint(1, 5)

vidas = 2

while vidas > 0:
    intento = int(input("Adivina el número entre 1 y 5: "))
    print(intento)
    if intento > 5 or intento <= 0:
        vidas -= 1 # De esta forma se reduce una vida.
        if vidas > 0:
            print(f"¿De verdad? He dicho entre 1 y 5. Te quedan {vidas} intentos.")
        else:
            print("¡Entre 1 y 5! La próxima vez tenlo en cuenta")
            print(f"El número correcto era {num_aleatorio}")
            break
    elif intento == num_aleatorio:
        print(f"¡Ganaste! Efectivamente el número correcto era el {num_aleatorio}")
        break
    else:
        vidas -= 1 # De esta forma se reduce una vida.
        if vidas > 0:
            print(f"Incorrecto. Te quedan {vidas} intentos.")
        else:
            print("¡Has perdido!")
            print(f"El número correcto era {num_aleatorio}")
            break
# Out:
# ¡Bienvenido de al juego! Elige sabiamente un número del 1 al 5
#
# 1
# Incorrecto. Te quedan 1 intentos.
# 2
# ¡Has perdido!
# El número correcto era 5

# %% [markdown]
# *Francisco Olivenza Millón*
