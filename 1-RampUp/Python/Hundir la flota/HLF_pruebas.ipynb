# %%
import random
import time
import os
from funciones import *

def partida_normal():
    tablero_oculto = [[" " for _ in range(10)] for _ in range(10)]
    tablero_maquina = [[" " for _ in range(10)] for _ in range(10)]
    x = []
    y = []
    l = []
    h = []
    colocar_barco_aleatorio(tablero_oculto, x, y, h, l)
    colocar_barco_jugador(tablero_maquina, x, y, h, l)

partida_normal()
# Out:
# Posición elegida: 1,9
# El barco no cabe en el tablero_maquina en esta posición.
# Posición elegida: 1,3
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]
# Posición elegida: 3,0
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]
# Posición elegida: 5,6
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', 'B', 'B', 'B', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]
# Posición elegida: 1,3
# Barco en esa posición. Escribe una nueva
# Barco cercano a posiciones cercanas. Escribe una nueva
# Barco en esa posición. Escribe una nueva
# Barco cercano a posiciones cercanas. Escribe una nueva
# Posición elegida: 5,0
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', 'B', 'B', 'B', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]
# Posición elegida: 7,3
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', 'B', 'B', 'B', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', 'B', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]
# Posición elegida: 0,0
# [['B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', 'B', 'B', 'B', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', 'B', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]
# Posición elegida: 0,9
# [['B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'B'],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', 'B', 'B', 'B', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', 'B', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]
# Posición elegida: 5,5
# Orientación no válida, elige horizontal o vertical:
# Posición elegida: 8,8
# [['B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'B'],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', 'B', 'B', 'B', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', 'B', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'B', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]
# Posición elegida: 9,4
# [['B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'B'],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', 'B', 'B', 'B', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', 'B', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'B', ' '],
#  [' ', ' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ']]
# Posición elegida: 9,0
# [['B', 'B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'B'],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', 'B', 'B', 'B', ' '],
#  ['B', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', 'B', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'B', ' '],
#  ['B', ' ', ' ', ' ', 'B', ' ', ' ', ' ', ' ', ' ']]

# %%
tablero_oculto = [[" " for _ in range(10)] for _ in range(10)]

colocar_barco_aleatorio(tablero_oculto, x, y, h, l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 tablero_oculto = [[" " for _ in range(10)] for _ in range(10)]
# ----> 3 colocar_barco_aleatorio(tablero_oculto, x, y, h, l)
#
# NameError: name 'x' is not defined

# %%
import random
import time
import os
from funciones import *

tablero_oculto = [[" " for _ in range(10)] for _ in range(10)]
tablero_maquina = [[" " for _ in range(10)] for _ in range(10)]

def turnos_prueba(tablero_maquina,tablero_oculto):
    contador_turnos = 0
    while True:
        contador_turnos += 1
        print("Turno máquina 1")
        time.sleep(1)
        disparar_maquina(tablero_maquina)
        if todos_los_barcos_hundidos(tablero_maquina) == True:
            print("¡Ha ganado!")
            print(f"Máquina 1 ha ganado en {contador_turnos} turnos.")
            break
        time.sleep(1)
        print("Turno máquina 2")
        disparar_maquina_2(tablero_oculto)
        if todos_los_barcos_hundidos(tablero_oculto) == True:
            print("¡Ha ganado!")
            print(f"Máquina 2 ha ganado en {contador_turnos} turnos.")
            break
    imprimir_tablero(contador_turnos)
    continuar = input("¿Volver al menú principal? (s/n): ").strip().lower()
    if continuar != "s":
        print("Volviendo al menú principal...")
        time.sleep(2)
        True

    time.sleep(5)
    os.system("cls")

turnos_prueba(tablero_maquina,tablero_oculto)
# Out:
# Turno máquina 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 37
#      34     time.sleep(5)
#      35     os.system("cls")
# ---> 37 turnos_prueba(tablero_maquina,tablero_oculto)
#
# Cell In[4], line 15, in turnos_prueba(tablero_maquina, tablero_oculto)
#      13 print("Turno máquina 1")
#      14 time.sleep(1)
# ---> 15 disparar_maquina(tablero_maquina)
#      16 if todos_los_barcos_hundidos(tablero_maquina) == True:
#      17     print("¡Ha ganado!")
#
# File c:\Users\Francisco\TheBridge\2503_dsft_thebridge_FranOlivenza\1-RampUp\Python\Hundir la flota\funciones.py:221, in disparar_maquina(tablero_maquina)
#     219 j = random.randint(0,9)
#     220 # Solicita esas dos coordenadas a la máquina
# --> 221 imprimir_tablero(f"Tu enemigo ha disparado a la posición [{i},{j}] y el resultado es:")
#     222 # Dispara y comprueba dónde ha impactado.
#     223 # Si acierta
#     224 if tablero_maquina[i][j] == "B":
#
# File c:\Users\Francisco\TheBridge\2503_dsft_thebridge_FranOlivenza\1-RampUp\Python\Hundir la flota\funciones.py:25, in imprimir_tablero(tablero)
#      22 def imprimir_tablero(tablero):
#      23     # Con esta función se genera un tablero con el índice horizontal y vertical, así como una cuadrícula.
#      24     # Esto permite ser más preciso con tus tiradas y que la pantalla quede más clara.
# ---> 25     tablero_con_indices = [[f"{i}"] + fila for i, fila in enumerate(tablero)]
#      26     # Crear encabezado de columnas
#      27     encabezado = [" "] + [f"{i}" for i in range(10)]
#
# File c:\Users\Francisco\TheBridge\2503_dsft_thebridge_FranOlivenza\1-RampUp\Python\Hundir la flota\funciones.py:25, in <listcomp>(.0)
#      22 def imprimir_tablero(tablero):
#      23     # Con esta función se genera un tablero con el índice horizontal y vertical, así como una cuadrícula.
#      24     # Esto permite ser más preciso con tus tiradas y que la pantalla quede más clara.
# ---> 25     tablero_con_indices = [[f"{i}"] + fila for i, fila in enumerate(tablero)]
#      26     # Crear encabezado de columnas
#      27     encabezado = [" "] + [f"{i}" for i in range(10)]
#
# TypeError: can only concatenate list (not "str") to list
